# %%
# Importing the necessary libraries for the project. 
import pandas as pd 
import yfinance as yf
import numpy as np # for numerical operations
import seaborn as sns #visualisation
import matplotlib.pyplot as plt # visualization
# %matplotlib inline 
import matplotlib.ticker as ticker # Library to customize ticks
from datetime import date
import matplotlib.dates as mdates
from scipy import stats
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller, kpss
from math import sqrt
# ParameterSampler for randomized hyperparameter sampling, optimizing model parameters in cross-validation.
from sklearn.model_selection import ParameterSampler
# pmdarima's auto_arima for automated selection of the best ARIMA parameters based on AIC/BIC scores.
from pmdarima import auto_arima
# Mean Squared Error and Mean Absolute Error metrics from sklearn for evaluating model accuracy.
from sklearn.metrics import mean_squared_error, mean_absolute_error
# TimeSeriesSplit for cross-validation with time series data to preserve the temporal ordering of data.
from sklearn.model_selection import TimeSeriesSplit, ParameterGrid
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.stats.diagnostic import het_arch

import warnings # filter warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Testing baseline SARIMA with exogenous variables (SARIMAX).
#
# - **Evaluation of final baseline model will be performed between the comparison of best model with and withou exogenous variables**

# %%
# Importing the dataset after the Log Returns transformation.
df1 = pd.read_csv('df1.csv', index_col=0, parse_dates=True)

# Along with the importation, the code will set the date as the index, value of 0 because is the first column.
## Setting parse_dates=true to ensure the dates are in datetime, making more appropriate for ML models.

# %%
df1.head()
# Out:
#                Close     lag_1     lag_4  rolling_mean_4w  rolling_mean_12w  \
# Date
# 2004-04-01  0.012635  0.031461 -0.023861         0.003674          0.000735
# 2004-04-08 -0.010896  0.012635 -0.000125         0.000981         -0.001424
# 2004-04-15 -0.003623 -0.010896 -0.029274         0.007394         -0.000325
# 2004-04-22 -0.001496 -0.003623  0.031461        -0.000845         -0.000305
# 2004-04-29 -0.000784 -0.001496  0.012635        -0.004200         -0.002649
#
#             volatility_4w
# Date
# 2004-04-01     117.596902
# 2004-04-08     117.741650
# 2004-04-15       0.776477
# 2004-04-22       0.623353
# 2004-04-29       0.647610

# %%
df1.describe()
# Out:
#              Close        lag_1        lag_4  rolling_mean_4w  \
# count  1031.000000  1031.000000  1031.000000      1031.000000
# mean      0.001575     0.001608     0.001508         0.001578
# std       0.020723     0.020744     0.020750         0.009796
# min      -0.069935    -0.069935    -0.069935        -0.051352
# 25%      -0.007633    -0.007633    -0.007858        -0.003032
# 50%       0.003635     0.003666     0.003626         0.002937
# 75%       0.013568     0.013643     0.013514         0.007596
# max       0.051947     0.051947     0.051947         0.031089
#
#        rolling_mean_12w  volatility_4w
# count       1031.000000    1031.000000
# mean           0.001516       7.731465
# std            0.005364      23.505939
# min           -0.026288       0.154122
# 25%           -0.001013       1.538535
# 50%            0.002346       2.585030
# 75%            0.004979       6.157669
# max            0.019145     338.128664

# %%
# Define the selected exogenous variables
ex1 = df1[['rolling_mean_4w', 'rolling_mean_12w', 'volatility_4w', 'lag_1', 'lag_4']]

# %%
# Define the split index for the train-test split (e.g., 85% train, 15% test)
split_index = int(0.85 * len(df1))

# Target variable split
train = df1['Close'][:split_index]
test = df1['Close'][split_index:]

# Exogenous variables split
exo_train = ex1[['rolling_mean_4w', 'rolling_mean_12w', 'volatility_4w', 'lag_1', 'lag_4']][:split_index]
exo_test = ex1[['rolling_mean_4w', 'rolling_mean_12w', 'volatility_4w', 'lag_1', 'lag_4']][split_index:]

# %% [markdown]
# - SARIMAX model being tested by random parameters with yearly seasonality (12 weeks).

# %% [markdown]
# The workflow of SARIMAX will follow the same path as the SARIMA:
# - Random parameter: Random values, starting point for hyper-parameter tunning.
#
# - Hyper-parameter tunning: Auto-arima and Random Search. The first will search through combinations that has the lower AIC value and the second will be performed along with cross validation techniques searching for the best RMSE.
#
# - Cross-Validation: Time-Series and Fixed Rolling Window.
#
# - Residuals: The analysis will be performed on the best model.
#
# **The evaluation of results and performance of each model will be at the end, when all models have being applied along with cross-validation techniques**.
#
#
#
#
#
#
# Performing auto-arima to find optimal parameters using two different frequencies monthly and quaterly.

# %%
# Define SARIMAX model 
sarimax_model = SARIMAX(train, order=(2, 0, 1), seasonal_order=(1, 0, 2, 12), exog=exo_train)
sarimax_final_fitted = sarimax_model.fit(disp=False)

# Print summary
print(sarimax_final_fitted.summary())

# Calculate RMSE on training data.
train_predictions = sarimax_final_fitted.predict(start=0, end=len(train)-1, exog=exo_train)
train_rmse = mean_squared_error(train, train_predictions, squared=False)

# Calculate MAE on training data.
train_mae = mean_absolute_error(train, train_predictions)

# Calculate RMSE on test data.
test_predictions = sarimax_final_fitted.forecast(steps=len(test), exog=exo_test)
test_rmse = mean_squared_error(test, test_predictions, squared=False)

# Calculate MAE on test data.
test_mae = mean_absolute_error(test, test_predictions)

# Calculate Directional Accuracy on Training Data.
train_direction_accuracy = np.mean(
    np.sign(train_predictions[:-1] - train_predictions[1:]) == np.sign(train[:-1] - train[1:]))

# Calculate Directional Accuracy on Test Data.
test_direction_accuracy = np.mean(
    np.sign(test_predictions[:-1] - test_predictions[1:]) == np.sign(test[:-1] - test[1:]))

# Print evaluation metrics.
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_direction_accuracy * 100:.2f}%")
print(f"Directional Accuracy on Test Data: {test_direction_accuracy * 100:.2f}%")

# Plot the actual vs. predicted values for training and test sets.
plt.figure(figsize=(12, 6))
plt.plot(train.index, train, label="Actual - Train", color='blue')
plt.plot(test.index, test, label="Actual - Test", color='orange')

# Plot predictions on training and test set.
plt.plot(train.index, train_predictions, label="Predicted - Train", linestyle='--', color='green')
plt.plot(test.index, test_predictions, label="Predicted - Test", linestyle='--', color='red')

# Finalize the plot.
plt.legend()
plt.title("Actual vs. Predicted Values for Training and Test Sets")
plt.xlabel("Time")
plt.ylabel("Values")
plt.show()
# Out:
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                   Close   No. Observations:                  876
# Model:             SARIMAX(2, 0, 1)x(1, 0, [1, 2], 12)   Log Likelihood                2476.997
# Date:                                 Thu, 07 Nov 2024   AIC                          -4929.995
# Time:                                         11:20:19   BIC                          -4872.690
# Sample:                                     04-01-2004   HQIC                         -4908.076
#                                           - 01-07-2021
# Covariance Type:                                   opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# rolling_mean_4w      1.4016      0.084     16.747      0.000       1.238       1.566
# rolling_mean_12w    -0.0584      0.112     -0.520      0.603      -0.278       0.162
# volatility_4w     1.078e-06   2.64e-05      0.041      0.967   -5.06e-05    5.28e-05
# lag_1               -0.3577      0.040     -9.023      0.000      -0.435      -0.280
# lag_4                0.0173      0.024      0.716      0.474      -0.030       0.065
# ar.L1                0.7345      0.065     11.279      0.000       0.607       0.862
# ar.L2               -0.4637      0.037    -12.421      0.000      -0.537      -0.391
# ma.L1               -0.6016      0.106     -5.686      0.000      -0.809      -0.394
# ar.S.L12            -0.1673      3.400     -0.049      0.961      -6.831       6.497
# ma.S.L12             0.1475      3.400      0.043      0.965      -6.516       6.811
# ma.S.L24            -0.0124      0.071     -0.175      0.861      -0.151       0.126
# sigma2               0.0002   1.03e-05     20.575      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.11   Jarque-Bera (JB):                67.26
# Prob(Q):                              0.08   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.85   Skew:                            -0.10
# Prob(H) (two-sided):                  0.15   Kurtosis:                         4.34
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Training RMSE: 0.014307480399504762
# Test RMSE: 0.018923065798875503
# Training MAE: 0.010467187354238822
# Test MAE: 0.014813455717897467
# Directional Accuracy on Training Data: 99.77%
# Directional Accuracy on Test Data: 98.71%

# %%
# Sets random seed for reproducibility.
np.random.seed(42)

# Perform auto_arima with specified seed and exogenous variables.
auto_model = auto_arima(train, 
                        exogenous=exo_train, 
                        seasonal=True,
                        m=4,  # Set seasonality period, e.g., 52 for weekly data with yearly seasonality.
                        trace=True,  # Prints the model selection process.
                        error_action='ignore',  # Ignore models that fail to fit.
                        suppress_warnings=True,  # Suppress warnings.
                        stepwise=True,  # Stepwise approach for faster search.
                        random=True,  # Random search.
                        random_state=42,  # Seed for reproducibility.
                        n_fits=50)  # Number of models to try.

# Print the best model found.
print(auto_model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[4] intercept   : AIC=inf, Time=2.25 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=-4339.778, Time=0.31 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=-4339.128, Time=0.66 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=-4339.189, Time=0.75 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=-4336.565, Time=0.23 sec
#  ARIMA(0,0,0)(1,0,0)[4] intercept   : AIC=-4338.081, Time=0.74 sec
#  ARIMA(0,0,0)(0,0,1)[4] intercept   : AIC=-4337.971, Time=0.32 sec
#  ARIMA(0,0,0)(1,0,1)[4] intercept   : AIC=-4338.113, Time=0.65 sec
#  ARIMA(1,0,0)(0,0,0)[4] intercept   : AIC=-4340.851, Time=0.27 sec
#  ARIMA(1,0,0)(0,0,1)[4] intercept   : AIC=-4339.096, Time=2.04 sec
#  ARIMA(1,0,0)(1,0,1)[4] intercept   : AIC=-4339.085, Time=1.43 sec
#  ARIMA(2,0,0)(0,0,0)[4] intercept   : AIC=-4339.098, Time=0.60 sec
#  ARIMA(1,0,1)(0,0,0)[4] intercept   : AIC=-4339.059, Time=0.54 sec
#  ARIMA(0,0,1)(0,0,0)[4] intercept   : AIC=-4340.943, Time=0.33 sec
#  ARIMA(0,0,1)(1,0,0)[4] intercept   : AIC=-4339.220, Time=0.64 sec
#  ARIMA(0,0,1)(1,0,1)[4] intercept   : AIC=-4339.172, Time=1.11 sec
#  ARIMA(0,0,2)(0,0,0)[4] intercept   : AIC=-4339.083, Time=0.38 sec
#  ARIMA(1,0,2)(0,0,0)[4] intercept   : AIC=-4337.039, Time=0.60 sec
#  ARIMA(0,0,1)(0,0,0)[4]             : AIC=-4337.070, Time=0.30 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[4] intercept
# Total fit time: 14.214 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  876
# Model:               SARIMAX(0, 0, 1)   Log Likelihood                2173.471
# Date:                Thu, 07 Nov 2024   AIC                          -4340.943
# Time:                        11:20:34   BIC                          -4326.616
# Sample:                    04-01-2004   HQIC                         -4335.463
#                          - 01-07-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0016      0.001      2.128      0.033       0.000       0.003
# ma.L1         -0.0599      0.025     -2.368      0.018      -0.109      -0.010
# sigma2         0.0004   1.56e-05     26.276      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               235.13
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.83   Skew:                            -0.85
# Prob(H) (two-sided):                  0.11   Kurtosis:                         4.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Define SARIMAX model.
sarimax_model = SARIMAX(train, order=(0, 0, 1), seasonal_order=(0, 0, 0, 4), exog=exo_train)
sarimax_final_fitted = sarimax_model.fit(disp=False)

# Print summary.
print(sarimax_final_fitted.summary())

# Calculate RMSE on training data.
train_predictions = sarimax_final_fitted.predict(start=0, end=len(train)-1, exog=exo_train)
train_rmse = mean_squared_error(train, train_predictions, squared=False)

# Calculate MAE on training data.
train_mae = mean_absolute_error(train, train_predictions)

# Calculate RMSE on test data.
test_predictions = sarimax_final_fitted.forecast(steps=len(test), exog=exo_test)
test_rmse = mean_squared_error(test, test_predictions, squared=False)

# Calculate MAE on test data.
test_mae = mean_absolute_error(test, test_predictions)

# Calculate Directional Accuracy on Training Data.
train_direction_accuracy = np.mean(
    np.sign(train_predictions[:-1] - train_predictions[1:]) == np.sign(train[:-1] - train[1:]))

# Calculate Directional Accuracy on Test Data.
test_direction_accuracy = np.mean(
    np.sign(test_predictions[:-1] - test_predictions[1:]) == np.sign(test[:-1] - test[1:]))

# Print evaluation metrics.
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_direction_accuracy * 100:.2f}%")
print(f"Directional Accuracy on Test Data: {test_direction_accuracy * 100:.2f}%")

# Plot the actual vs. predicted values for training and test sets.
plt.figure(figsize=(12, 6))
plt.plot(train.index, train, label="Actual - Train", color='blue')
plt.plot(test.index, test, label="Actual - Test", color='orange')

# Plot predictions on training and test set.
plt.plot(train.index, train_predictions, label="Predicted - Train", linestyle='--', color='green')
plt.plot(test.index, test_predictions, label="Predicted - Test", linestyle='--', color='red')

# Finalize the plot.
plt.legend()
plt.title("Actual vs. Predicted Values for Training and Test Sets")
plt.xlabel("Time")
plt.ylabel("Values")
plt.show()
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  876
# Model:               SARIMAX(0, 0, 1)   Log Likelihood                2508.926
# Date:                Thu, 07 Nov 2024   AIC                          -5003.852
# Time:                        11:20:36   BIC                          -4970.424
# Sample:                    04-01-2004   HQIC                         -4991.066
#                          - 01-07-2021
# Covariance Type:                  opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# rolling_mean_4w      1.9155      0.090     21.285      0.000       1.739       2.092
# rolling_mean_12w     0.1292      0.132      0.982      0.326      -0.129       0.387
# volatility_4w    -3.924e-06   5.16e-05     -0.076      0.939      -0.000    9.72e-05
# lag_1               -0.8463      0.029    -29.498      0.000      -0.903      -0.790
# lag_4                0.1035      0.014      7.330      0.000       0.076       0.131
# ma.L1                0.8612      0.063     13.705      0.000       0.738       0.984
# sigma2               0.0002   9.43e-06     21.701      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.84   Jarque-Bera (JB):               182.62
# Prob(Q):                              0.05   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.83   Skew:                             0.46
# Prob(H) (two-sided):                  0.12   Kurtosis:                         5.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Training RMSE: 0.01379765477760987
# Test RMSE: 0.02164365346616176
# Training MAE: 0.010028601170829701
# Test MAE: 0.017044175447287816
# Directional Accuracy on Training Data: 99.77%
# Directional Accuracy on Test Data: 98.71%

# %%
# Sets random seed for reproducibility
np.random.seed(42)

# Perform auto_arima with specified seed and exogenous variables
auto_model = auto_arima(train, 
                        exogenous=exo_train, 
                        seasonal=True,
                        m=12,  # Set seasonality period, e.g., 12 for weekly data with quaterly seasonality
                        trace=True,  # Prints the model selection process
                        error_action='ignore',  # Ignore models that fail to fit
                        suppress_warnings=True,  # Suppress warnings
                        stepwise=True,  # Stepwise approach for faster search
                        random=True,  # Random search
                        random_state=42,  # Seed for reproducibility
                        n_fits=50)  # Number of models to try

# Print the best model found
print(auto_model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=6.41 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=-4339.778, Time=0.33 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=-4341.316, Time=1.72 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=-4341.459, Time=0.58 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=-4336.565, Time=0.26 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=-4340.943, Time=0.31 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=-4339.420, Time=1.37 sec
#  ARIMA(0,0,1)(0,0,2)[12] intercept   : AIC=-4339.562, Time=4.30 sec
#  ARIMA(0,0,1)(1,0,0)[12] intercept   : AIC=-4341.399, Time=0.86 sec
#  ARIMA(0,0,1)(1,0,2)[12] intercept   : AIC=-4337.567, Time=3.35 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : AIC=-4340.320, Time=2.57 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=-4339.534, Time=1.73 sec
#  ARIMA(0,0,2)(0,0,1)[12] intercept   : AIC=-4339.565, Time=0.98 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=-4341.377, Time=0.95 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=-4337.577, Time=2.61 sec
#  ARIMA(0,0,1)(0,0,1)[12]             : AIC=-4336.958, Time=0.49 sec
#
# Best model:  ARIMA(0,0,1)(0,0,1)[12] intercept
# Total fit time: 28.845 seconds
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  876
# Model:             SARIMAX(0, 0, 1)x(0, 0, 1, 12)   Log Likelihood                2174.730
# Date:                            Thu, 07 Nov 2024   AIC                          -4341.459
# Time:                                    11:21:06   BIC                          -4322.358
# Sample:                                04-01-2004   HQIC                         -4334.153
#                                      - 01-07-2021
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0016      0.001      2.222      0.026       0.000       0.003
# ma.L1         -0.0599      0.026     -2.343      0.019      -0.110      -0.010
# ma.S.L12      -0.0527      0.032     -1.646      0.100      -0.115       0.010
# sigma2         0.0004   1.57e-05     26.074      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               236.66
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.83   Skew:                            -0.86
# Prob(H) (two-sided):                  0.11   Kurtosis:                         4.87
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Define SARIMAX model 
sarimax_model = SARIMAX(train, order=(0, 0, 1), seasonal_order=(0, 0, 1, 12), exog=exo_train)
sarimax_final_fitted = sarimax_model.fit(disp=False)

# Print summary
print(sarimax_final_fitted.summary())

# Calculate RMSE on training data
train_predictions = sarimax_final_fitted.predict(start=0, end=len(train)-1, exog=exo_train)
train_rmse = mean_squared_error(train, train_predictions, squared=False)

# Calculate MAE on training data
train_mae = mean_absolute_error(train, train_predictions)

# Calculate RMSE on test data
test_predictions = sarimax_final_fitted.forecast(steps=len(test), exog=exo_test)
test_rmse = mean_squared_error(test, test_predictions, squared=False)

# Calculate MAE on test data
test_mae = mean_absolute_error(test, test_predictions)

# Calculate Directional Accuracy on Training Data
train_direction_accuracy = np.mean(
    np.sign(train_predictions[:-1] - train_predictions[1:]) == np.sign(train[:-1] - train[1:]))

# Calculate Directional Accuracy on Test Data
test_direction_accuracy = np.mean(
    np.sign(test_predictions[:-1] - test_predictions[1:]) == np.sign(test[:-1] - test[1:]))

# Print evaluation metrics
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_direction_accuracy * 100:.2f}%")
print(f"Directional Accuracy on Test Data: {test_direction_accuracy * 100:.2f}%")

# Plot the actual vs. predicted values for training and test sets
plt.figure(figsize=(12, 6))
plt.plot(train.index, train, label="Actual - Train", color='blue')
plt.plot(test.index, test, label="Actual - Test", color='orange')

# Plot predictions on training and test set
plt.plot(train.index, train_predictions, label="Predicted - Train", linestyle='--', color='green')
plt.plot(test.index, test_predictions, label="Predicted - Test", linestyle='--', color='red')

# Finalize the plot
plt.legend()
plt.title("Actual vs. Predicted Values for Training and Test Sets")
plt.xlabel("Time")
plt.ylabel("Values")
plt.show()
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Close   No. Observations:                  876
# Model:             SARIMAX(0, 0, 1)x(0, 0, 1, 12)   Log Likelihood                2373.790
# Date:                            Thu, 07 Nov 2024   AIC                          -4731.579
# Time:                                    11:21:09   BIC                          -4693.376
# Sample:                                04-01-2004   HQIC                         -4716.966
#                                      - 01-07-2021
# Covariance Type:                              opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# rolling_mean_4w      1.4016      0.082     17.039      0.000       1.240       1.563
# rolling_mean_12w    -0.0583      0.102     -0.571      0.568      -0.259       0.142
# volatility_4w     6.996e-06   4.59e-05      0.152      0.879    -8.3e-05     9.7e-05
# lag_1               -0.3577      0.066     -5.419      0.000      -0.487      -0.228
# lag_4                0.0173      0.032      0.534      0.594      -0.046       0.081
# ma.L1                0.1330      0.082      1.615      0.106      -0.028       0.294
# ma.S.L12            -0.0214      0.033     -0.641      0.521      -0.087       0.044
# sigma2               0.0003   1.24e-05     20.944      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   4.79   Jarque-Bera (JB):                91.23
# Prob(Q):                              0.03   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.86   Skew:                             0.27
# Prob(H) (two-sided):                  0.21   Kurtosis:                         4.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Training RMSE: 0.016103111310592548
# Test RMSE: 0.018923831749591308
# Training MAE: 0.011818087795054355
# Test MAE: 0.014793848991083621
# Directional Accuracy on Training Data: 99.77%
# Directional Accuracy on Test Data: 98.71%

# %% [markdown]
# - With different types of hyper-parameter tunning, the random search will be selected to to find the optimal parameters (30 different). The selection is due to the trade-off between range of values and computational resources (takes too long to run). In addition, a random state will be added to ensure reproducibility (same results).
# - Grid Search was attempted but it was extremely computational expensive (especially for m=52).
#
# Instead of applying the random search on a simple train and test set, the approach will be performed along with cross validation, providing a more reliable RMSE across differend folds.
#
# <b> Monthly Frequency (m=4) </b>

# %%
# Define the train-test split indices for time-series cross-validation.
n_splits = 4
test_window = 50  # Number of rows for each test set.
initial_train_window = len(train) - n_splits * test_window

# Parameter grid and random sampling as defined in your prompt.
param_grid = {
    'p': [0, 1, 2, 3],
    'd': [0, 1],
    'q': [0, 1, 2, 3],
    'P': [0, 1, 2],
    'D': [0, 1],
    'Q': [0, 1, 2],
    'm': [4]
}

# Number of combinations to try.
n_iter_search = 30  # Number of random parameter combinations.
# Creates a list of the parameters tested and random_state is being called to reproduce same combinations. 
random_param_list = list(ParameterSampler(param_grid, n_iter_search, random_state=42))

# Function to evaluate SARIMA with cross-validation.
def evaluate_sarima_cv_rmse(params): # Defining params (p,q,d) and seasonal (p,q,d,m).
    """
    Performs rolling cross-validation on SARIMA model with specified parameters and returns average RMSE.
    """
    p, d, q = params['p'], params['d'], params['q']
    P, D, Q, m = params['P'], params['D'], params['Q'], params['m']
    
    rmse_scores = []  # Store RMSE for each fold.
    
    for i in range(n_splits):
        # Define the train and test indices for this fold.
        train_end = initial_train_window + i * test_window
        test_end = train_end + test_window
        
        y_train, y_test = train[:train_end], train[train_end:test_end]
        X_train, X_test = exo_train[:train_end], exo_train[train_end:test_end]
        
        try:
            # Fit SARIMA model on the current training set
            model = sm.tsa.statespace.SARIMAX(y_train,
                                              order=(p, d, q),
                                              seasonal_order=(P, D, Q, m),
                                              exog=X_train,
                                              enforce_stationarity=False,
                                              enforce_invertibility=False)
            result = model.fit(disp=False)

            # Forecast on the current test set (one-step ahead only)
            forecast = result.predict(start=len(y_train), end=len(y_train) + len(y_test) - 1, exog=X_test)
            
            # Calculate RMSE for this fold.
            rmse = mean_squared_error(y_test, forecast, squared=False)
            rmse_scores.append(rmse)
        except Exception as e:
            print(f"Failed to fit model for parameters {params} on fold {i+1}: {e}")
            return np.inf  # Return large RMSE if fitting fails for this parameter set.
    
    # Calculate the average RMSE across all folds.
    avg_rmse = np.mean(rmse_scores)
    return avg_rmse

# Initialize variables to store the best parameters and lowest average RMSE.
best_rmse = np.inf
best_params = None

# Perform random search with cross-validation.
for params in random_param_list:
    print(f"Testing SARIMA parameters: {params}") # Prints the parameters tested.
    
    # Evaluate SARIMA model with cross-validation.
    rmse = evaluate_sarima_cv_rmse(params)
    
    # Track the best performing parameters and RMSE.
    if rmse < best_rmse:
        best_rmse = rmse
        best_params = params

    print(f"Average RMSE across folds: {rmse}") # Prints the RMSE avg of each combinations.

# Output the best parameters and the best RMSE score
print(f"Best parameters: {best_params}") # Returns the best combinations among the 30 attempts.
print(f"Best average RMSE across folds: {best_rmse}") # Returns the best avg RMSE among the 30 attempts.
# Out:
# Testing SARIMA parameters: {'q': 2, 'p': 2, 'm': 4, 'd': 0, 'Q': 1, 'P': 2, 'D': 0}
# Average RMSE across folds: 0.016439549216232113
# Testing SARIMA parameters: {'q': 2, 'p': 1, 'm': 4, 'd': 1, 'Q': 0, 'P': 1, 'D': 0}
# Average RMSE across folds: 0.026279316655272153
# Testing SARIMA parameters: {'q': 2, 'p': 2, 'm': 4, 'd': 1, 'Q': 1, 'P': 0, 'D': 1}
# Average RMSE across folds: 0.023694616550966503
# Testing SARIMA parameters: {'q': 2, 'p': 0, 'm': 4, 'd': 1, 'Q': 0, 'P': 2, 'D': 1}
# Average RMSE across folds: 0.025113979534594495
# Testing SARIMA parameters: {'q': 2, 'p': 0, 'm': 4, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}
# Average RMSE across folds: 0.03139788307055266
# Testing SARIMA parameters: {'q': 0, 'p': 0, 'm': 4, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}
# Average RMSE across folds: 0.09444391212407384
# Testing SARIMA parameters: {'q': 3, 'p': 0, 'm': 4, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}
# Average RMSE across folds: 0.01651306001692053
# Testing SARIMA parameters: {'q': 1, 'p': 3, 'm': 4, 'd': 1, 'Q': 0, 'P': 0, 'D': 0}
# Average RMSE across folds: 0.02675056988432497
# Testing SARIMA parameters: {'q': 2, 'p': 0, 'm': 4, 'd': 1, 'Q': 2, 'P': 0, 'D': 0}
# Average RMSE across folds: 0.025893590684445522
# Testing SARIMA parameters: {'q': 0, 'p': 3, 'm': 4, 'd': 1, 'Q': 2, 'P': 0, 'D': 1}
# Average RMSE across folds: 0.027716869566952976
# Testing SARIMA parameters: {'q': 2, 'p': 1, 'm': 4, 'd': 1, 'Q': 2, 'P': 1, 'D': 1}
# Average RMSE across folds: 0.024025486538019444
# Testing SARIMA parameters: {'q': 3, 'p': 3, 'm': 4, 'd': 1, 'Q': 1, 'P': 1, 'D': 1}
# Average RMSE across folds: 0.025109814679884074
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 4, 'd': 1, 'Q': 2, 'P': 2, 'D': 0}
# Average RMSE across folds: 0.026584170767505313
# Testing SARIMA parameters: {'q': 0, 'p': 1, 'm': 4, 'd': 0, 'Q': 2, 'P': 0, 'D': 1}
# Average RMSE across folds: 0.017069417866608885
# Testing SARIMA parameters: {'q': 2, 'p': 1, 'm': 4, 'd': 1, 'Q': 1, 'P': 2, 'D': 1}
# Average RMSE across folds: 0.02525529771966139
# Testing SARIMA parameters: {'q': 3, 'p': 1, 'm': 4, 'd': 0, 'Q': 2, 'P': 1, 'D': 0}
# Average RMSE across folds: 0.016423555063349714
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 4, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}
# Average RMSE across folds: 0.016430444149838096
# Testing SARIMA parameters: {'q': 3, 'p': 1, 'm': 4, 'd': 1, 'Q': 1, 'P': 0, 'D': 0}
# Average RMSE across folds: 0.028329358352899434
# Testing SARIMA parameters: {'q': 0, 'p': 3, 'm': 4, 'd': 0, 'Q': 1, 'P': 2, 'D': 1}
# Average RMSE across folds: 0.01851811016566833
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 4, 'd': 1, 'Q': 1, 'P': 1, 'D': 0}
# Average RMSE across folds: 0.02663755777879681
# Testing SARIMA parameters: {'q': 1, 'p': 1, 'm': 4, 'd': 1, 'Q': 2, 'P': 2, 'D': 1}
# Average RMSE across folds: 0.025554132504636937
# Testing SARIMA parameters: {'q': 2, 'p': 2, 'm': 4, 'd': 1, 'Q': 2, 'P': 0, 'D': 0}
# Average RMSE across folds: 0.02738453660296414
# Testing SARIMA parameters: {'q': 1, 'p': 1, 'm': 4, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}
# Average RMSE across folds: 0.08801313160054273
# Testing SARIMA parameters: {'q': 0, 'p': 1, 'm': 4, 'd': 0, 'Q': 1, 'P': 2, 'D': 0}
# Average RMSE across folds: 0.01644228699401184
# Testing SARIMA parameters: {'q': 2, 'p': 0, 'm': 4, 'd': 0, 'Q': 1, 'P': 2, 'D': 1}
# Average RMSE across folds: 0.018579522421377385
# Testing SARIMA parameters: {'q': 0, 'p': 0, 'm': 4, 'd': 1, 'Q': 2, 'P': 1, 'D': 0}
# Average RMSE across folds: 0.028296913517086693
# Testing SARIMA parameters: {'q': 3, 'p': 1, 'm': 4, 'd': 1, 'Q': 1, 'P': 2, 'D': 0}
# Average RMSE across folds: 0.028117357176929342
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 4, 'd': 0, 'Q': 1, 'P': 1, 'D': 1}
# Average RMSE across folds: 0.018732889639155578
# Testing SARIMA parameters: {'q': 0, 'p': 3, 'm': 4, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}
# Average RMSE across folds: 0.017152222209403056
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 4, 'd': 0, 'Q': 2, 'P': 0, 'D': 0}
# Average RMSE across folds: 0.01642944316278779
# Best parameters: {'q': 3, 'p': 1, 'm': 4, 'd': 0, 'Q': 2, 'P': 1, 'D': 0}
# Best average RMSE across folds: 0.016423555063349714

# %%
# Time-Series CV. 
## Define SARIMAX model.
sarimax_model = SARIMAX(train, order=(1, 0, 3), seasonal_order=(1, 0, 2, 4), exog=exo_train)
sarimax_final_fitted = sarimax_model.fit(disp=False)

# Print summary.
print(sarimax_final_fitted.summary())

# Calculate RMSE on training data.
train_predictions = sarimax_final_fitted.predict(start=0, end=len(train)-1, exog=exo_train)
train_rmse = mean_squared_error(train, train_predictions, squared=False)

# Calculate MAE on training data.
train_mae = mean_absolute_error(train, train_predictions)

# Calculate RMSE on test data.
test_predictions = sarimax_final_fitted.forecast(steps=len(test), exog=exo_test)
test_rmse = mean_squared_error(test, test_predictions, squared=False)

# Calculate MAE on test data.
test_mae = mean_absolute_error(test, test_predictions)

# Calculate Directional Accuracy on Training Data.
train_direction_accuracy = np.mean(
    np.sign(train_predictions[:-1] - train_predictions[1:]) == np.sign(train[:-1] - train[1:]))

# Calculate Directional Accuracy on Test Data.
test_direction_accuracy = np.mean(
    np.sign(test_predictions[:-1] - test_predictions[1:]) == np.sign(test[:-1] - test[1:]))

# Print evaluation metrics.
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_direction_accuracy * 100:.2f}%")
print(f"Directional Accuracy on Test Data: {test_direction_accuracy * 100:.2f}%")

# Plot the actual vs. predicted values for training and test sets.
plt.figure(figsize=(12, 6))
plt.plot(train.index, train, label="Actual - Train", color='blue')
plt.plot(test.index, test, label="Actual - Test", color='orange')

# Plot predictions on training and test set.
plt.plot(train.index, train_predictions, label="Predicted - Train", linestyle='--', color='green')
plt.plot(test.index, test_predictions, label="Predicted - Test", linestyle='--', color='red')

# Finalize the plot.
plt.legend()
plt.title("Actual vs. Predicted Values for Training and Test Sets")
plt.xlabel("Time")
plt.ylabel("Values")
plt.show()
# Out:
#                                        SARIMAX Results
# ==============================================================================================
# Dep. Variable:                                  Close   No. Observations:                  876
# Model:             SARIMAX(1, 0, 3)x(1, 0, [1, 2], 4)   Log Likelihood                2521.764
# Date:                                Thu, 07 Nov 2024   AIC                          -5017.528
# Time:                                        11:29:11   BIC                          -4955.448
# Sample:                                    04-01-2004   HQIC                         -4993.782
#                                          - 01-07-2021
# Covariance Type:                                  opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# rolling_mean_4w      1.4016      0.102     13.724      0.000       1.201       1.602
# rolling_mean_12w    -0.0584      0.114     -0.511      0.609      -0.282       0.165
# volatility_4w    -1.823e-06   1.38e-05     -0.132      0.895   -2.89e-05    2.52e-05
# lag_1               -0.3577      0.183     -1.960      0.050      -0.715    7.66e-05
# lag_4                0.0173      0.136      0.127      0.899      -0.249       0.284
# ar.L1                0.0480      0.456      0.105      0.916      -0.846       0.942
# ma.L1                0.0106      0.273      0.039      0.969      -0.524       0.545
# ma.L2               -0.4275      0.059     -7.301      0.000      -0.542      -0.313
# ma.L3               -0.4157      0.232     -1.789      0.074      -0.871       0.040
# ar.S.L4              0.0076      0.501      0.015      0.988      -0.973       0.989
# ma.S.L4             -0.0025      0.495     -0.005      0.996      -0.973       0.968
# ma.S.L8              0.0708      0.032      2.195      0.028       0.008       0.134
# sigma2               0.0002   1.51e-05     13.086      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.79   Jarque-Bera (JB):                87.99
# Prob(Q):                              0.18   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.85   Skew:                            -0.34
# Prob(H) (two-sided):                  0.17   Kurtosis:                         4.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Training RMSE: 0.013581173335885058
# Test RMSE: 0.01892468574052594
# Training MAE: 0.00988754900205325
# Test MAE: 0.014837417425420881
# Directional Accuracy on Training Data: 99.77%
# Directional Accuracy on Test Data: 98.71%

# %% [markdown]
# - The present parameter presents the lower AIC at thi point (-5117.63).
# - The model summary shows that the feature rolling_mean_4w has great impact, meanwhile lag_1 has a negative effect.

# %%
# Define a 4 week (one month) horizon for evaluation metrics.
horizon = 4

# Calculate RMSE over the 4 week (one month) horizon.
fours_weeks_rmse = np.sqrt(mean_squared_error(test[horizon:], test_predictions[:-horizon]))

# Calculate MAE over 4 week (one month) horizon.
fours_weeks_mae = mean_absolute_error(test[horizon:], test_predictions[:-horizon])

# Calculate 4 week (one month) Directional Accuracy.
direction_accuracy = np.mean(
    np.sign(test_predictions[:-horizon] - test_predictions[horizon:]) == 
    np.sign(test[:-horizon] - test[horizon:])
)

# Print evaluation metrics.
print("4 week (one month) Horizon RMSE:", fours_weeks_rmse)
print("4 week (one month) Horizon MAE:", fours_weeks_mae)
print(f"4 week (one month) Horizon Directional Accuracy: {direction_accuracy * 100:.2f}%")

# Plot the actual vs. predicted values for training and test sets.
plt.figure(figsize=(12, 6))
plt.plot(train.index, train, label="Actual - Train", color='blue')
plt.plot(test.index, test, label="Actual - Test", color='orange')

# Plot predictions on test set.
plt.plot(test.index, test_predictions, label="Predicted - Test", linestyle='--', color='red')

# Finalize the plot.
plt.legend()
plt.title("Actual vs. Predicted Values for Test Set (5-Day Horizon)")
plt.xlabel("Time")
plt.ylabel("Values")
plt.show()
# Out:
# 4 week (one month) Horizon RMSE: 0.027205557849831353
# 4 week (one month) Horizon MAE: 0.02099406775735901
# 4 week (one month) Horizon Directional Accuracy: 94.84%

# %%
# Define parameter grid for SARIMA.
param_grid = {
    'p': [0, 1, 2, 3],
    'd': [0, 1],
    'q': [0, 1, 2, 3],
    'P': [0, 1, 2],
    'D': [0, 1],
    'Q': [0, 1, 2],
    'm': [4]  # Seasonal period.
}

# Number of random parameter combinations to try.
n_iter_search = 30  
# Creates a list of the parameters tested and random_state is being called to reproduce same combinations. 
random_param_list = list(ParameterSampler(param_grid, n_iter_search, random_state=42))

# Initialize to track the best parameters and lowest average RMSE.
best_rmse = np.inf
best_params = None

window_size = 300  # Fixed training window size.
test_size = 50  # Fixed test window size.

# Loop over each parameter combination in the random sample.
for params in random_param_list:
    print(f"Testing SARIMA parameters: {params}")
    p, d, q = params['p'], params['d'], params['q']
    P, D, Q, m = params['P'], params['D'], params['Q'], params['m']
    
    rolling_rmses = []  # Store RMSE for each rolling window iteration.
    
    # Perform rolling window cross-validation.
    for i in range(0, len(train) - window_size - test_size, test_size):
        y_train = train[i:i + window_size]
        y_test = train[i + window_size:i + window_size + test_size]
        X_train = exo_train[i:i + window_size]
        X_test = exo_train[i + window_size:i + window_size + test_size]

        try:
            # Fit SARIMA model on the current training set with sampled parameters.
            model = sm.tsa.statespace.SARIMAX(
                y_train,
                order=(p, d, q),
                seasonal_order=(P, D, Q, m),
                exog=X_train,
                enforce_stationarity=False,
                enforce_invertibility=False
            )
            result = model.fit(disp=False)

            # Forecast on the current test set (only one-step ahead).
            forecast = result.predict(start=len(y_train), end=len(y_train) + len(y_test) - 1, exog=X_test)
            
            # Calculate RMSE for this fold.
            rmse = np.sqrt(mean_squared_error(y_test, forecast))
            rolling_rmses.append(rmse)
        except Exception as e:
            print(f"Failed to fit model on iteration {i} with parameters {params}: {e}")
            rolling_rmses.append(np.inf)  # Assign high error if fitting fails.
    
    # Calculate the average RMSE across all rolling windows for the current parameter set
    avg_rolling_rmse = np.mean(rolling_rmses)
    print(f"Average Rolling Window RMSE for parameters {params}: {avg_rolling_rmse}")

    # Update best parameters if the current RMSE is lower
    if avg_rolling_rmse < best_rmse:
        best_rmse = avg_rolling_rmse
        best_params = params

# Output the best parameters and the best RMSE score
print(f"Best parameters: {best_params}") # Returns the best combinations among the 30 attempts.
print(f"Best average Rolling Window RMSE: {best_rmse}") # Returns the best avg RMSE among the 30 attempts.
# Out:
# Testing SARIMA parameters: {'q': 2, 'p': 2, 'm': 4, 'd': 0, 'Q': 1, 'P': 2, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 2, 'm': 4, 'd': 0, 'Q': 1, 'P': 2, 'D': 0}: 0.015287716908057254
# Testing SARIMA parameters: {'q': 2, 'p': 1, 'm': 4, 'd': 1, 'Q': 0, 'P': 1, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 1, 'm': 4, 'd': 1, 'Q': 0, 'P': 1, 'D': 0}: 0.023505473534793875
# Testing SARIMA parameters: {'q': 2, 'p': 2, 'm': 4, 'd': 1, 'Q': 1, 'P': 0, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 2, 'm': 4, 'd': 1, 'Q': 1, 'P': 0, 'D': 1}: 0.021820709868128195
# Testing SARIMA parameters: {'q': 2, 'p': 0, 'm': 4, 'd': 1, 'Q': 0, 'P': 2, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 0, 'm': 4, 'd': 1, 'Q': 0, 'P': 2, 'D': 1}: 0.03053255339827333
# Testing SARIMA parameters: {'q': 2, 'p': 0, 'm': 4, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 0, 'm': 4, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}: 0.026211974071496034
# Testing SARIMA parameters: {'q': 0, 'p': 0, 'm': 4, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 0, 'p': 0, 'm': 4, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}: 0.08200206343664856
# Testing SARIMA parameters: {'q': 3, 'p': 0, 'm': 4, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 3, 'p': 0, 'm': 4, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}: 0.014920134849853793
# Testing SARIMA parameters: {'q': 1, 'p': 3, 'm': 4, 'd': 1, 'Q': 0, 'P': 0, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 1, 'p': 3, 'm': 4, 'd': 1, 'Q': 0, 'P': 0, 'D': 0}: 0.027962437024011987
# Testing SARIMA parameters: {'q': 2, 'p': 0, 'm': 4, 'd': 1, 'Q': 2, 'P': 0, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 0, 'm': 4, 'd': 1, 'Q': 2, 'P': 0, 'D': 0}: 0.026115267397629413
# Testing SARIMA parameters: {'q': 0, 'p': 3, 'm': 4, 'd': 1, 'Q': 2, 'P': 0, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 0, 'p': 3, 'm': 4, 'd': 1, 'Q': 2, 'P': 0, 'D': 1}: 0.02610261252480695
# Testing SARIMA parameters: {'q': 2, 'p': 1, 'm': 4, 'd': 1, 'Q': 2, 'P': 1, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 1, 'm': 4, 'd': 1, 'Q': 2, 'P': 1, 'D': 1}: 0.02120496938920707
# Testing SARIMA parameters: {'q': 3, 'p': 3, 'm': 4, 'd': 1, 'Q': 1, 'P': 1, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 3, 'p': 3, 'm': 4, 'd': 1, 'Q': 1, 'P': 1, 'D': 1}: 0.029248985234591032
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 4, 'd': 1, 'Q': 2, 'P': 2, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 1, 'p': 2, 'm': 4, 'd': 1, 'Q': 2, 'P': 2, 'D': 0}: 0.027672902946831848
# Testing SARIMA parameters: {'q': 0, 'p': 1, 'm': 4, 'd': 0, 'Q': 2, 'P': 0, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 0, 'p': 1, 'm': 4, 'd': 0, 'Q': 2, 'P': 0, 'D': 1}: 0.016632562558961683
# Testing SARIMA parameters: {'q': 2, 'p': 1, 'm': 4, 'd': 1, 'Q': 1, 'P': 2, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 1, 'm': 4, 'd': 1, 'Q': 1, 'P': 2, 'D': 1}: 0.02261597397789444
# Testing SARIMA parameters: {'q': 3, 'p': 1, 'm': 4, 'd': 0, 'Q': 2, 'P': 1, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 3, 'p': 1, 'm': 4, 'd': 0, 'Q': 2, 'P': 1, 'D': 0}: 0.014932994032602983
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 4, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 1, 'p': 2, 'm': 4, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}: 0.015038716308139004
# Testing SARIMA parameters: {'q': 3, 'p': 1, 'm': 4, 'd': 1, 'Q': 1, 'P': 0, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 3, 'p': 1, 'm': 4, 'd': 1, 'Q': 1, 'P': 0, 'D': 0}: 0.02488822933265832
# Testing SARIMA parameters: {'q': 0, 'p': 3, 'm': 4, 'd': 0, 'Q': 1, 'P': 2, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 0, 'p': 3, 'm': 4, 'd': 0, 'Q': 1, 'P': 2, 'D': 1}: 0.019219737089062574
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 4, 'd': 1, 'Q': 1, 'P': 1, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 1, 'p': 2, 'm': 4, 'd': 1, 'Q': 1, 'P': 1, 'D': 0}: 0.026007255168128338
# Testing SARIMA parameters: {'q': 1, 'p': 1, 'm': 4, 'd': 1, 'Q': 2, 'P': 2, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 1, 'p': 1, 'm': 4, 'd': 1, 'Q': 2, 'P': 2, 'D': 1}: 0.03307023066736674
# Testing SARIMA parameters: {'q': 2, 'p': 2, 'm': 4, 'd': 1, 'Q': 2, 'P': 0, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 2, 'm': 4, 'd': 1, 'Q': 2, 'P': 0, 'D': 0}: 0.024521150030439844
# Testing SARIMA parameters: {'q': 1, 'p': 1, 'm': 4, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 1, 'p': 1, 'm': 4, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}: 0.09977089163418519
# Testing SARIMA parameters: {'q': 0, 'p': 1, 'm': 4, 'd': 0, 'Q': 1, 'P': 2, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 0, 'p': 1, 'm': 4, 'd': 0, 'Q': 1, 'P': 2, 'D': 0}: 0.015346577159885168
# Testing SARIMA parameters: {'q': 2, 'p': 0, 'm': 4, 'd': 0, 'Q': 1, 'P': 2, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 0, 'm': 4, 'd': 0, 'Q': 1, 'P': 2, 'D': 1}: 0.01846073779151896
# Testing SARIMA parameters: {'q': 0, 'p': 0, 'm': 4, 'd': 1, 'Q': 2, 'P': 1, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 0, 'p': 0, 'm': 4, 'd': 1, 'Q': 2, 'P': 1, 'D': 0}: 0.027747337061228585
# Testing SARIMA parameters: {'q': 3, 'p': 1, 'm': 4, 'd': 1, 'Q': 1, 'P': 2, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 3, 'p': 1, 'm': 4, 'd': 1, 'Q': 1, 'P': 2, 'D': 0}: 0.025195754204923548
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 4, 'd': 0, 'Q': 1, 'P': 1, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 1, 'p': 2, 'm': 4, 'd': 0, 'Q': 1, 'P': 1, 'D': 1}: 0.01848680772121655
# Testing SARIMA parameters: {'q': 0, 'p': 3, 'm': 4, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 0, 'p': 3, 'm': 4, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}: 0.01525663339016427
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 4, 'd': 0, 'Q': 2, 'P': 0, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 1, 'p': 2, 'm': 4, 'd': 0, 'Q': 2, 'P': 0, 'D': 0}: 0.015048094060807345
# Best parameters: {'q': 3, 'p': 0, 'm': 4, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}
# Best average Rolling Window RMSE: 0.014920134849853793

# %%
# Fixed Rolling window CV. 
## Define SARIMAX model. 
sarimax_model = SARIMAX(train, order=(0, 0, 3), seasonal_order=(2, 0, 2, 4), exog=exo_train)
sarimax_final_fitted = sarimax_model.fit(disp=False)

# Print summary.
print(sarimax_final_fitted.summary())

# Calculate RMSE on training data.
train_predictions = sarimax_final_fitted.predict(start=0, end=len(train)-1, exog=exo_train)
train_rmse = mean_squared_error(train, train_predictions, squared=False)

# Calculate MAE on training data.
train_mae = mean_absolute_error(train, train_predictions)

# Calculate RMSE on test data.
test_predictions = sarimax_final_fitted.forecast(steps=len(test), exog=exo_test)
test_rmse = mean_squared_error(test, test_predictions, squared=False)

# Calculate MAE on test data.
test_mae = mean_absolute_error(test, test_predictions)

# Calculate Directional Accuracy on Training Data.
train_direction_accuracy = np.mean(
    np.sign(train_predictions[:-1] - train_predictions[1:]) == np.sign(train[:-1] - train[1:]))

# Calculate Directional Accuracy on Test Data.
test_direction_accuracy = np.mean(
    np.sign(test_predictions[:-1] - test_predictions[1:]) == np.sign(test[:-1] - test[1:]))

# Print evaluation metrics.
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_direction_accuracy * 100:.2f}%")
print(f"Directional Accuracy on Test Data: {test_direction_accuracy * 100:.2f}%")

# Plot the actual vs. predicted values for training and test sets.
plt.figure(figsize=(12, 6))
plt.plot(train.index, train, label="Actual - Train", color='blue')
plt.plot(test.index, test, label="Actual - Test", color='orange')

# Plot predictions on training and test set.
plt.plot(train.index, train_predictions, label="Predicted - Train", linestyle='--', color='green')
plt.plot(test.index, test_predictions, label="Predicted - Test", linestyle='--', color='red')

# Finalize the plot.
plt.legend()
plt.title("Actual vs. Predicted Values for Training and Test Sets")
plt.xlabel("Time")
plt.ylabel("Values")
plt.show()
# Out:
#                                        SARIMAX Results
# ==============================================================================================
# Dep. Variable:                                  Close   No. Observations:                  876
# Model:             SARIMAX(0, 0, 3)x(2, 0, [1, 2], 4)   Log Likelihood                2520.498
# Date:                                Thu, 07 Nov 2024   AIC                          -5014.996
# Time:                                        11:32:58   BIC                          -4952.916
# Sample:                                    04-01-2004   HQIC                         -4991.250
#                                          - 01-07-2021
# Covariance Type:                                  opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# rolling_mean_4w      1.4016      0.100     14.015      0.000       1.206       1.598
# rolling_mean_12w    -0.0584      0.119     -0.491      0.623      -0.291       0.175
# volatility_4w    -2.876e-06   1.43e-05     -0.201      0.841   -3.09e-05    2.52e-05
# lag_1               -0.3577      0.115     -3.103      0.002      -0.584      -0.132
# lag_4                0.0172      0.038      0.455      0.649      -0.057       0.091
# ma.L1                0.0580      0.154      0.376      0.707      -0.244       0.360
# ma.L2               -0.4235      0.051     -8.357      0.000      -0.523      -0.324
# ma.L3               -0.4343      0.051     -8.506      0.000      -0.534      -0.334
# ar.S.L4              0.0089      0.471      0.019      0.985      -0.914       0.931
# ar.S.L8              0.0838      0.431      0.195      0.846      -0.760       0.928
# ma.S.L4             -0.0049      0.471     -0.010      0.992      -0.929       0.919
# ma.S.L8             -0.0131      0.427     -0.031      0.976      -0.851       0.824
# sigma2               0.0002    1.4e-05     13.156      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.37   Jarque-Bera (JB):                86.97
# Prob(Q):                              0.24   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.86   Skew:                            -0.32
# Prob(H) (two-sided):                  0.19   Kurtosis:                         4.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Training RMSE: 0.013617424630886148
# Test RMSE: 0.018933694136607362
# Training MAE: 0.009906421834581902
# Test MAE: 0.014849388284239083
# Directional Accuracy on Training Data: 99.77%
# Directional Accuracy on Test Data: 98.71%

# %%
# Define a 4 week (one month) horizon for evaluation metrics.
horizon = 4

# Calculate RMSE over the 4 week (one month) horizon.
fours_weeks_rmse = np.sqrt(mean_squared_error(test[horizon:], test_predictions[:-horizon]))

# Calculate MAE over 4 week (one month) horizon.
fours_weeks_mae = mean_absolute_error(test[horizon:], test_predictions[:-horizon])

# Calculate 4 week (one month) Directional Accuracy.
direction_accuracy = np.mean(
    np.sign(test_predictions[:-horizon] - test_predictions[horizon:]) == 
    np.sign(test[:-horizon] - test[horizon:])
)

# Print evaluation metrics.
print("4 week (one month) Horizon RMSE:", fours_weeks_rmse)
print("4 week (one month) Horizon MAE:", fours_weeks_mae)
print(f"4 week (one month) Horizon Directional Accuracy: {direction_accuracy * 100:.2f}%")

# Plot the actual vs. predicted values for training and test sets.
plt.figure(figsize=(12, 6))
plt.plot(train.index, train, label="Actual - Train", color='blue')
plt.plot(test.index, test, label="Actual - Test", color='orange')

# Plot predictions on test set.
plt.plot(test.index, test_predictions, label="Predicted - Test", linestyle='--', color='red')

# Finalize the plot.
plt.legend()
plt.title("Actual vs. Predicted Values for Test Set (5-Day Horizon)")
plt.xlabel("Time")
plt.ylabel("Values")
plt.show()
# Out:
# 4 week (one month) Horizon RMSE: 0.027206412733342383
# 4 week (one month) Horizon MAE: 0.02099725380879987
# 4 week (one month) Horizon Directional Accuracy: 94.84%

# %% [markdown]
# <b> Quaterly frequency (m=12) </b>

# %%
# Define the train-test split indices for time-series cross-validation.
n_splits = 4
test_window = 50  # Number of rows for each test set.
initial_train_window = len(train) - n_splits * test_window

# Parameter grid and random sampling as defined in your prompt.
param_grid = {
    'p': [0, 1, 2, 3],
    'd': [0, 1],
    'q': [0, 1, 2, 3],
    'P': [0, 1, 2],
    'D': [0, 1],
    'Q': [0, 1, 2],
    'm': [12]
}

n_iter_search = 30  # Number of random parameter combinations.
# Creates a list of the parameters tested and random_state is being called to reproduce same combinations.
random_param_list = list(ParameterSampler(param_grid, n_iter_search, random_state=42))

# Updated function to evaluate SARIMA with cross-validation
def evaluate_sarima_cv_rmse(params): # Defining params (p,q,d) and seasonal (p,q,d,m).
    """
    Performs rolling cross-validation on SARIMA model with specified parameters and returns average RMSE.
    """
    p, d, q = params['p'], params['d'], params['q']
    P, D, Q, m = params['P'], params['D'], params['Q'], params['m']
    
    rmse_scores = []  # Store RMSE for each fold.
    
    for i in range(n_splits):
        # Define the train and test indices for this fold.
        train_end = initial_train_window + i * test_window
        test_end = train_end + test_window
        
        y_train, y_test = train[:train_end], train[train_end:test_end]
        X_train, X_test = exo_train[:train_end], exo_train[train_end:test_end]
        
        try:
            # Fit SARIMA model on the current training set.
            model = sm.tsa.statespace.SARIMAX(y_train,
                                              order=(p, d, q),
                                              seasonal_order=(P, D, Q, m),
                                              exog=X_train,
                                              enforce_stationarity=False,
                                              enforce_invertibility=False)
            result = model.fit(disp=False)

            # Forecast on the current test set (one-step ahead only).
            forecast = result.predict(start=len(y_train), end=len(y_train) + len(y_test) - 1, exog=X_test)
            
            # Calculate RMSE for this fold.
            rmse = mean_squared_error(y_test, forecast, squared=False)
            rmse_scores.append(rmse)
        except Exception as e:
            print(f"Failed to fit model for parameters {params} on fold {i+1}: {e}")
            return np.inf  # Return large RMSE if fitting fails for this parameter set.
    
    # Calculate the average RMSE across all folds.
    avg_rmse = np.mean(rmse_scores)
    return avg_rmse

# Initialize variables to store the best parameters and lowest average RMSE.
best_rmse = np.inf
best_params = None

# Perform random search with cross-validation.
for params in random_param_list:
    print(f"Testing SARIMA parameters: {params}") # Prints the parameters tested.
    
    # Evaluate SARIMA model with cross-validation.
    rmse = evaluate_sarima_cv_rmse(params)
    
    # Track the best performing parameters and RMSE.
    if rmse < best_rmse:
        best_rmse = rmse
        best_params = params

    print(f"Average RMSE across folds: {rmse}") # Prints the RMSE avg of each combinations.

# Output the best parameters and the best RMSE score.
print(f"Best parameters: {best_params}") # Returns the best combinations among the 30 attempts.
print(f"Best average RMSE across folds: {best_rmse}") # Returns the best avg RMSE among the 30 attempts.
# Out:
# Testing SARIMA parameters: {'q': 2, 'p': 2, 'm': 12, 'd': 0, 'Q': 1, 'P': 2, 'D': 0}
# Average RMSE across folds: 0.01656583352345243
# Testing SARIMA parameters: {'q': 2, 'p': 1, 'm': 12, 'd': 1, 'Q': 0, 'P': 1, 'D': 0}
# Average RMSE across folds: 0.027054542096896048
# Testing SARIMA parameters: {'q': 2, 'p': 2, 'm': 12, 'd': 1, 'Q': 1, 'P': 0, 'D': 1}
# Average RMSE across folds: 0.03224330997998976
# Testing SARIMA parameters: {'q': 2, 'p': 0, 'm': 12, 'd': 1, 'Q': 0, 'P': 2, 'D': 1}
# Average RMSE across folds: 0.033720696816152654
# Testing SARIMA parameters: {'q': 2, 'p': 0, 'm': 12, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}
# Average RMSE across folds: 0.03565111227401974
# Testing SARIMA parameters: {'q': 0, 'p': 0, 'm': 12, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}
# Average RMSE across folds: 0.03655693611192263
# Testing SARIMA parameters: {'q': 3, 'p': 0, 'm': 12, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}
# Average RMSE across folds: 0.016431659384905824
# Testing SARIMA parameters: {'q': 1, 'p': 3, 'm': 12, 'd': 1, 'Q': 0, 'P': 0, 'D': 0}
# Average RMSE across folds: 0.02675056988432497
# Testing SARIMA parameters: {'q': 2, 'p': 0, 'm': 12, 'd': 1, 'Q': 2, 'P': 0, 'D': 0}
# Average RMSE across folds: 0.025998860481640573
# Testing SARIMA parameters: {'q': 0, 'p': 3, 'm': 12, 'd': 1, 'Q': 2, 'P': 0, 'D': 1}
# Average RMSE across folds: 0.027937360156930477
# Testing SARIMA parameters: {'q': 2, 'p': 1, 'm': 12, 'd': 1, 'Q': 2, 'P': 1, 'D': 1}
# Average RMSE across folds: 0.030270877810217676
# Testing SARIMA parameters: {'q': 3, 'p': 3, 'm': 12, 'd': 1, 'Q': 1, 'P': 1, 'D': 1}
# Average RMSE across folds: 0.031974441534933735
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 12, 'd': 1, 'Q': 2, 'P': 2, 'D': 0}
# Average RMSE across folds: 0.0278268441068171
# Testing SARIMA parameters: {'q': 0, 'p': 1, 'm': 12, 'd': 0, 'Q': 2, 'P': 0, 'D': 1}
# Average RMSE across folds: 0.016813726689875602
# Testing SARIMA parameters: {'q': 2, 'p': 1, 'm': 12, 'd': 1, 'Q': 1, 'P': 2, 'D': 1}
# Average RMSE across folds: 0.03314850097492704
# Testing SARIMA parameters: {'q': 3, 'p': 1, 'm': 12, 'd': 0, 'Q': 2, 'P': 1, 'D': 0}
# Average RMSE across folds: 0.01639653529753241
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 12, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}
# Average RMSE across folds: 0.016707579217109803
# Testing SARIMA parameters: {'q': 3, 'p': 1, 'm': 12, 'd': 1, 'Q': 1, 'P': 0, 'D': 0}
# Average RMSE across folds: 0.02791754548450987
# Testing SARIMA parameters: {'q': 0, 'p': 3, 'm': 12, 'd': 0, 'Q': 1, 'P': 2, 'D': 1}
# Average RMSE across folds: 0.019090514721167587
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 12, 'd': 1, 'Q': 1, 'P': 1, 'D': 0}
# Average RMSE across folds: 0.027046250028846232
# Testing SARIMA parameters: {'q': 1, 'p': 1, 'm': 12, 'd': 1, 'Q': 2, 'P': 2, 'D': 1}
# Average RMSE across folds: 0.030086762459200295
# Testing SARIMA parameters: {'q': 2, 'p': 2, 'm': 12, 'd': 1, 'Q': 2, 'P': 0, 'D': 0}
# Average RMSE across folds: 0.028816558480052275
# Testing SARIMA parameters: {'q': 1, 'p': 1, 'm': 12, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}
# Average RMSE across folds: 0.042667200541734014
# Testing SARIMA parameters: {'q': 0, 'p': 1, 'm': 12, 'd': 0, 'Q': 1, 'P': 2, 'D': 0}
# Average RMSE across folds: 0.0164734722495382
# Testing SARIMA parameters: {'q': 2, 'p': 0, 'm': 12, 'd': 0, 'Q': 1, 'P': 2, 'D': 1}
# Average RMSE across folds: 0.020901889303545036
# Testing SARIMA parameters: {'q': 0, 'p': 0, 'm': 12, 'd': 1, 'Q': 2, 'P': 1, 'D': 0}
# Average RMSE across folds: 0.028310686168845627
# Testing SARIMA parameters: {'q': 3, 'p': 1, 'm': 12, 'd': 1, 'Q': 1, 'P': 2, 'D': 0}
# Average RMSE across folds: 0.027256365963050165
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 12, 'd': 0, 'Q': 1, 'P': 1, 'D': 1}
# Average RMSE across folds: 0.018290898669067003
# Testing SARIMA parameters: {'q': 0, 'p': 3, 'm': 12, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}
# Average RMSE across folds: 0.016477021566925654
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 12, 'd': 0, 'Q': 2, 'P': 0, 'D': 0}
# Average RMSE across folds: 0.0166043230408913
# Best parameters: {'q': 3, 'p': 1, 'm': 12, 'd': 0, 'Q': 2, 'P': 1, 'D': 0}
# Best average RMSE across folds: 0.01639653529753241

# %%
# Time-Series CV.
## Define SARIMAX model. 
sarimax_model = SARIMAX(train, order=(1, 0, 3), seasonal_order=(1, 0, 2, 12), exog=exo_train)
sarimax_final_fitted = sarimax_model.fit(disp=False)

# Print summary.
print(sarimax_final_fitted.summary())

# Calculate RMSE on training data.
train_predictions = sarimax_final_fitted.predict(start=0, end=len(train)-1, exog=exo_train)
train_rmse = mean_squared_error(train, train_predictions, squared=False)

# Calculate MAE on training data.
train_mae = mean_absolute_error(train, train_predictions)

# Calculate RMSE on test data.
test_predictions = sarimax_final_fitted.forecast(steps=len(test), exog=exo_test)
test_rmse = mean_squared_error(test, test_predictions, squared=False)

# Calculate MAE on test data.
test_mae = mean_absolute_error(test, test_predictions)

# Calculate Directional Accuracy on Training Data.
train_direction_accuracy = np.mean(
    np.sign(train_predictions[:-1] - train_predictions[1:]) == np.sign(train[:-1] - train[1:]))

# Calculate Directional Accuracy on Test Data.
test_direction_accuracy = np.mean(
    np.sign(test_predictions[:-1] - test_predictions[1:]) == np.sign(test[:-1] - test[1:]))

# Print evaluation metrics.
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_direction_accuracy * 100:.2f}%")
print(f"Directional Accuracy on Test Data: {test_direction_accuracy * 100:.2f}%")

# Plot the actual vs. predicted values for training and test sets.
plt.figure(figsize=(12, 6))
plt.plot(train.index, train, label="Actual - Train", color='blue')
plt.plot(test.index, test, label="Actual - Test", color='orange')

# Plot predictions on training and test set.
plt.plot(train.index, train_predictions, label="Predicted - Train", linestyle='--', color='green')
plt.plot(test.index, test_predictions, label="Predicted - Test", linestyle='--', color='red')

# Finalize the plot.
plt.legend()
plt.title("Actual vs. Predicted Values for Training and Test Sets")
plt.xlabel("Time")
plt.ylabel("Values")
plt.show()
# Out:
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                   Close   No. Observations:                  876
# Model:             SARIMAX(1, 0, 3)x(1, 0, [1, 2], 12)   Log Likelihood                2571.814
# Date:                                 Sun, 10 Nov 2024   AIC                          -5117.628
# Time:                                         18:13:30   BIC                          -5055.549
# Sample:                                     04-01-2004   HQIC                         -5093.883
#                                           - 01-07-2021
# Covariance Type:                                   opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# rolling_mean_4w      1.6479      0.071     23.374      0.000       1.510       1.786
# rolling_mean_12w    -0.0190      0.066     -0.289      0.773      -0.148       0.110
# volatility_4w    -9.313e-06   9.22e-06     -1.010      0.313   -2.74e-05    8.77e-06
# lag_1               -0.5461      0.064     -8.529      0.000      -0.672      -0.421
# lag_4               -0.0669      0.046     -1.466      0.143      -0.156       0.023
# ar.L1                0.0095      0.177      0.054      0.957      -0.337       0.356
# ma.L1                0.0537      0.123      0.435      0.664      -0.188       0.295
# ma.L2               -0.4778      0.053     -8.992      0.000      -0.582      -0.374
# ma.L3               -0.4290      0.106     -4.055      0.000      -0.636      -0.222
# ar.S.L12            -0.2063      0.018    -11.479      0.000      -0.242      -0.171
# ma.S.L12             0.1070      0.019      5.749      0.000       0.071       0.143
# ma.S.L24            -0.0205      0.031     -0.669      0.503      -0.081       0.040
# sigma2               0.0002   9.35e-06     17.597      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   5.98   Jarque-Bera (JB):                93.04
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.84   Skew:                            -0.30
# Prob(H) (two-sided):                  0.12   Kurtosis:                         4.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.17e+17. Standard errors may be unstable.
# Training RMSE: 0.012844322410895006
# Test RMSE: 0.01962481697132581
# Training MAE: 0.009441540120432355
# Test MAE: 0.015327287651180167
# Directional Accuracy on Training Data: 99.77%
# Directional Accuracy on Test Data: 98.71%

# %%
# Define a 4 week (one month) horizon for evaluation metrics.
horizon = 4

# Calculate RMSE over the 4 week (one month) horizon.
fours_weeks_rmse = np.sqrt(mean_squared_error(test[horizon:], test_predictions[:-horizon]))

# Calculate MAE over 4 week (one month) horizon.
fours_weeks_mae = mean_absolute_error(test[horizon:], test_predictions[:-horizon])

# Calculate 4 week (one month) Directional Accuracy.
direction_accuracy = np.mean(
    np.sign(test_predictions[:-horizon] - test_predictions[horizon:]) == 
    np.sign(test[:-horizon] - test[horizon:])
)

# Print evaluation metrics.
print("4 week (one month) Horizon RMSE:", fours_weeks_rmse)
print("4 week (one month) Horizon MAE:", fours_weeks_mae)
print(f"4 week (one month) Horizon Directional Accuracy: {direction_accuracy * 100:.2f}%")

# Plot the actual vs. predicted values for training and test sets.
plt.figure(figsize=(12, 6))
plt.plot(train.index, train, label="Actual - Train", color='blue')
plt.plot(test.index, test, label="Actual - Test", color='orange')

# Plot predictions on test set.
plt.plot(test.index, test_predictions, label="Predicted - Test", linestyle='--', color='red')

# Finalize the plot.
plt.legend()
plt.title("Actual vs. Predicted Values for Test Set (5-Day Horizon)")
plt.xlabel("Time")
plt.ylabel("Values")
plt.show()
# Out:
# 4 week (one month) Horizon RMSE: 0.028734191563165
# 4 week (one month) Horizon MAE: 0.022083582601103952
# 4 week (one month) Horizon Directional Accuracy: 94.84%

# %%
# Define parameter grid for SARIMA.
param_grid = {
    'p': [0, 1, 2, 3],
    'd': [0, 1],
    'q': [0, 1, 2, 3],
    'P': [0, 1, 2],
    'D': [0, 1],
    'Q': [0, 1, 2],
    'm': [12]  # Seasonal period.
}

# Number of random parameter combinations to try.
n_iter_search = 30  
# Creates a list of the parameters tested and random_state is being called to reproduce same combinations. 
random_param_list = list(ParameterSampler(param_grid, n_iter_search, random_state=42))

# Initialize to track the best parameters and lowest average RMSE
best_rmse = np.inf
best_params = None

# Fixed Rolling Window Cross-Validation Configuration
window_size = 300  # Training window size to align with initial TSCV window.
test_size = 50     # Test window size to match TSCV.

# Loop over each parameter combination in the random sample.
for params in random_param_list:
    print(f"Testing SARIMA parameters: {params}")
    p, d, q = params['p'], params['d'], params['q']
    P, D, Q, m = params['P'], params['D'], params['Q'], params['m']
    
    rolling_rmses = []  # Store RMSE for each rolling window iteration.
    
    # Perform rolling window cross-validation.
    for i in range(0, len(train) - window_size - test_size, test_size):
        y_train = train[i:i + window_size]
        y_test = train[i + window_size:i + window_size + test_size]
        X_train = exo_train[i:i + window_size]
        X_test = exo_train[i + window_size:i + window_size + test_size]

        try:
            # Fit SARIMA model on the current training set with sampled parameters.
            model = sm.tsa.statespace.SARIMAX(
                y_train,
                order=(p, d, q),
                seasonal_order=(P, D, Q, m),
                exog=X_train,
                enforce_stationarity=False,
                enforce_invertibility=False
            )
            result = model.fit(disp=False)

            # Forecast on the current test set (only one-step ahead).
            forecast = result.predict(start=len(y_train), end=len(y_train) + len(y_test) - 1, exog=X_test)
            
            # Calculate RMSE for this fold.
            rmse = np.sqrt(mean_squared_error(y_test, forecast))
            rolling_rmses.append(rmse)
        except Exception as e:
            print(f"Failed to fit model on iteration {i} with parameters {params}: {e}")
            rolling_rmses.append(np.inf)  # Assign high error if fitting fails.
    
    # Calculate the average RMSE across all rolling windows for the current parameter set.
    avg_rolling_rmse = np.mean(rolling_rmses)
    print(f"Average Rolling Window RMSE for parameters {params}: {avg_rolling_rmse}")

    # Update best parameters if the current RMSE is lower.
    if avg_rolling_rmse < best_rmse:
        best_rmse = avg_rolling_rmse
        best_params = params

# Output the best parameters and the best RMSE score.
print(f"Best parameters: {best_params}")  # Returns the best combinations among the 30 attempts.
print(f"Best average Rolling Window RMSE: {best_rmse}") # Returns the best avg RMSE among the 30 attempts.
# Out:
# Testing SARIMA parameters: {'q': 2, 'p': 2, 'm': 12, 'd': 0, 'Q': 1, 'P': 2, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 2, 'm': 12, 'd': 0, 'Q': 1, 'P': 2, 'D': 0}: 0.01537876747704418
# Testing SARIMA parameters: {'q': 2, 'p': 1, 'm': 12, 'd': 1, 'Q': 0, 'P': 1, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 1, 'm': 12, 'd': 1, 'Q': 0, 'P': 1, 'D': 0}: 0.023657310102617346
# Testing SARIMA parameters: {'q': 2, 'p': 2, 'm': 12, 'd': 1, 'Q': 1, 'P': 0, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 2, 'm': 12, 'd': 1, 'Q': 1, 'P': 0, 'D': 1}: 0.0276248081123065
# Testing SARIMA parameters: {'q': 2, 'p': 0, 'm': 12, 'd': 1, 'Q': 0, 'P': 2, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 0, 'm': 12, 'd': 1, 'Q': 0, 'P': 2, 'D': 1}: 0.03723788139074072
# Testing SARIMA parameters: {'q': 2, 'p': 0, 'm': 12, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 0, 'm': 12, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}: 0.0401103694498165
# Testing SARIMA parameters: {'q': 0, 'p': 0, 'm': 12, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 0, 'p': 0, 'm': 12, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}: 0.03826510198793221
# Testing SARIMA parameters: {'q': 3, 'p': 0, 'm': 12, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 3, 'p': 0, 'm': 12, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}: 0.014874239452308952
# Testing SARIMA parameters: {'q': 1, 'p': 3, 'm': 12, 'd': 1, 'Q': 0, 'P': 0, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 1, 'p': 3, 'm': 12, 'd': 1, 'Q': 0, 'P': 0, 'D': 0}: 0.027962437024011987
# Testing SARIMA parameters: {'q': 2, 'p': 0, 'm': 12, 'd': 1, 'Q': 2, 'P': 0, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 0, 'm': 12, 'd': 1, 'Q': 2, 'P': 0, 'D': 0}: 0.025871991106871616
# Testing SARIMA parameters: {'q': 0, 'p': 3, 'm': 12, 'd': 1, 'Q': 2, 'P': 0, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 0, 'p': 3, 'm': 12, 'd': 1, 'Q': 2, 'P': 0, 'D': 1}: 0.030024019414316813
# Testing SARIMA parameters: {'q': 2, 'p': 1, 'm': 12, 'd': 1, 'Q': 2, 'P': 1, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 1, 'm': 12, 'd': 1, 'Q': 2, 'P': 1, 'D': 1}: 0.026197300166974857
# Testing SARIMA parameters: {'q': 3, 'p': 3, 'm': 12, 'd': 1, 'Q': 1, 'P': 1, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 3, 'p': 3, 'm': 12, 'd': 1, 'Q': 1, 'P': 1, 'D': 1}: 0.035869017322317794
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 12, 'd': 1, 'Q': 2, 'P': 2, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 1, 'p': 2, 'm': 12, 'd': 1, 'Q': 2, 'P': 2, 'D': 0}: 0.027388279588416744
# Testing SARIMA parameters: {'q': 0, 'p': 1, 'm': 12, 'd': 0, 'Q': 2, 'P': 0, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 0, 'p': 1, 'm': 12, 'd': 0, 'Q': 2, 'P': 0, 'D': 1}: 0.016022624629486226
# Testing SARIMA parameters: {'q': 2, 'p': 1, 'm': 12, 'd': 1, 'Q': 1, 'P': 2, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 1, 'm': 12, 'd': 1, 'Q': 1, 'P': 2, 'D': 1}: 0.03511638188979661
# Testing SARIMA parameters: {'q': 3, 'p': 1, 'm': 12, 'd': 0, 'Q': 2, 'P': 1, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 3, 'p': 1, 'm': 12, 'd': 0, 'Q': 2, 'P': 1, 'D': 0}: 0.014835598755589752
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 12, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 1, 'p': 2, 'm': 12, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}: 0.014984253390485652
# Testing SARIMA parameters: {'q': 3, 'p': 1, 'm': 12, 'd': 1, 'Q': 1, 'P': 0, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 3, 'p': 1, 'm': 12, 'd': 1, 'Q': 1, 'P': 0, 'D': 0}: 0.024649687198286366
# Testing SARIMA parameters: {'q': 0, 'p': 3, 'm': 12, 'd': 0, 'Q': 1, 'P': 2, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 0, 'p': 3, 'm': 12, 'd': 0, 'Q': 1, 'P': 2, 'D': 1}: 0.018288952054011428
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 12, 'd': 1, 'Q': 1, 'P': 1, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 1, 'p': 2, 'm': 12, 'd': 1, 'Q': 1, 'P': 1, 'D': 0}: 0.027040581759079762
# Testing SARIMA parameters: {'q': 1, 'p': 1, 'm': 12, 'd': 1, 'Q': 2, 'P': 2, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 1, 'p': 1, 'm': 12, 'd': 1, 'Q': 2, 'P': 2, 'D': 1}: 0.03571216563825672
# Testing SARIMA parameters: {'q': 2, 'p': 2, 'm': 12, 'd': 1, 'Q': 2, 'P': 0, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 2, 'm': 12, 'd': 1, 'Q': 2, 'P': 0, 'D': 0}: 0.02428348471560804
# Testing SARIMA parameters: {'q': 1, 'p': 1, 'm': 12, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 1, 'p': 1, 'm': 12, 'd': 1, 'Q': 0, 'P': 1, 'D': 1}: 0.049902943159446385
# Testing SARIMA parameters: {'q': 0, 'p': 1, 'm': 12, 'd': 0, 'Q': 1, 'P': 2, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 0, 'p': 1, 'm': 12, 'd': 0, 'Q': 1, 'P': 2, 'D': 0}: 0.015350896084645205
# Testing SARIMA parameters: {'q': 2, 'p': 0, 'm': 12, 'd': 0, 'Q': 1, 'P': 2, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 2, 'p': 0, 'm': 12, 'd': 0, 'Q': 1, 'P': 2, 'D': 1}: 0.018446584781600692
# Testing SARIMA parameters: {'q': 0, 'p': 0, 'm': 12, 'd': 1, 'Q': 2, 'P': 1, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 0, 'p': 0, 'm': 12, 'd': 1, 'Q': 2, 'P': 1, 'D': 0}: 0.02755178508119165
# Testing SARIMA parameters: {'q': 3, 'p': 1, 'm': 12, 'd': 1, 'Q': 1, 'P': 2, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 3, 'p': 1, 'm': 12, 'd': 1, 'Q': 1, 'P': 2, 'D': 0}: 0.02446539290970736
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 12, 'd': 0, 'Q': 1, 'P': 1, 'D': 1}
# Average Rolling Window RMSE for parameters {'q': 1, 'p': 2, 'm': 12, 'd': 0, 'Q': 1, 'P': 1, 'D': 1}: 0.016789393305938382
# Testing SARIMA parameters: {'q': 0, 'p': 3, 'm': 12, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 0, 'p': 3, 'm': 12, 'd': 0, 'Q': 2, 'P': 2, 'D': 0}: 0.015312207825924006
# Testing SARIMA parameters: {'q': 1, 'p': 2, 'm': 12, 'd': 0, 'Q': 2, 'P': 0, 'D': 0}
# Average Rolling Window RMSE for parameters {'q': 1, 'p': 2, 'm': 12, 'd': 0, 'Q': 2, 'P': 0, 'D': 0}: 0.015061016906230624
# Best parameters: {'q': 3, 'p': 1, 'm': 12, 'd': 0, 'Q': 2, 'P': 1, 'D': 0}
# Best average Rolling Window RMSE: 0.014835598755589752

# %%
# Fixed Rolling window CV. 
## Define SARIMAX model.
sarimax_model = SARIMAX(train, order=(2, 0, 1), seasonal_order=(0, 0, 2, 12), exog=exo_train)
sarimax_final_fitted = sarimax_model.fit(disp=False)

# Print summary.
print(sarimax_final_fitted.summary())

# Calculate RMSE on training data.
train_predictions = sarimax_final_fitted.predict(start=0, end=len(train)-1, exog=exo_train)
train_rmse = mean_squared_error(train, train_predictions, squared=False)

# Calculate MAE on training data.
train_mae = mean_absolute_error(train, train_predictions)

# Calculate RMSE on test data.
test_predictions = sarimax_final_fitted.forecast(steps=len(test), exog=exo_test)
test_rmse = mean_squared_error(test, test_predictions, squared=False)

# Calculate MAE on test data.
test_mae = mean_absolute_error(test, test_predictions)

# Calculate Directional Accuracy on Training Data.
train_direction_accuracy = np.mean(
    np.sign(train_predictions[:-1] - train_predictions[1:]) == np.sign(train[:-1] - train[1:]))

# Calculate Directional Accuracy on Test Data.
test_direction_accuracy = np.mean(
    np.sign(test_predictions[:-1] - test_predictions[1:]) == np.sign(test[:-1] - test[1:]))

# Print evaluation metrics.
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_direction_accuracy * 100:.2f}%")
print(f"Directional Accuracy on Test Data: {test_direction_accuracy * 100:.2f}%")

# Plot the actual vs. predicted values for training and test sets.
plt.figure(figsize=(12, 6))
plt.plot(train.index, train, label="Actual - Train", color='blue')
plt.plot(test.index, test, label="Actual - Test", color='orange')

# Plot predictions on training and test set.
plt.plot(train.index, train_predictions, label="Predicted - Train", linestyle='--', color='green')
plt.plot(test.index, test_predictions, label="Predicted - Test", linestyle='--', color='red')

# Finalize the plot.
plt.legend()
plt.title("Actual vs. Predicted Values for Training and Test Sets")
plt.xlabel("Time")
plt.ylabel("Values")
plt.show()
# Out:
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                   Close   No. Observations:                  876
# Model:             SARIMAX(2, 0, 1)x(0, 0, [1, 2], 12)   Log Likelihood                2476.983
# Date:                                 Thu, 07 Nov 2024   AIC                          -4931.966
# Time:                                         13:46:42   BIC                          -4879.437
# Sample:                                     04-01-2004   HQIC                         -4911.874
#                                           - 01-07-2021
# Covariance Type:                                   opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# rolling_mean_4w      1.4016      0.084     16.755      0.000       1.238       1.566
# rolling_mean_12w    -0.0584      0.112     -0.522      0.602      -0.278       0.161
# volatility_4w     1.098e-06   2.63e-05      0.042      0.967   -5.05e-05    5.27e-05
# lag_1               -0.3577      0.040     -9.050      0.000      -0.435      -0.280
# lag_4                0.0173      0.024      0.718      0.473      -0.030       0.064
# ar.L1                0.7345      0.065     11.280      0.000       0.607       0.862
# ar.L2               -0.4637      0.037    -12.475      0.000      -0.537      -0.391
# ma.L1               -0.6016      0.106     -5.691      0.000      -0.809      -0.394
# ma.S.L12            -0.0192      0.034     -0.561      0.575      -0.086       0.048
# ma.S.L24            -0.0087      0.032     -0.272      0.785      -0.071       0.054
# sigma2               0.0002   1.03e-05     20.601      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.11   Jarque-Bera (JB):                67.26
# Prob(Q):                              0.08   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.84   Skew:                            -0.10
# Prob(H) (two-sided):                  0.15   Kurtosis:                         4.34
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Training RMSE: 0.01430772331074011
# Test RMSE: 0.018922153718355882
# Training MAE: 0.010466496576820476
# Test MAE: 0.014810669219755353
# Directional Accuracy on Training Data: 99.77%
# Directional Accuracy on Test Data: 98.71%

# %%
# Define a 4 week (one month) horizon for evaluation metrics.
horizon = 4

# Calculate RMSE over the 4 week (one month) horizon.
fours_weeks_rmse = np.sqrt(mean_squared_error(test[horizon:], test_predictions[:-horizon]))

# Calculate MAE over 4 week (one month) horizon.
fours_weeks_mae = mean_absolute_error(test[horizon:], test_predictions[:-horizon])

# Calculate MAPE over the 4 week (one month) horizon.
fours_weeks_mape = np.mean(np.abs((test[horizon:] - test_predictions[:-horizon]) / test[horizon:])) * 100

# Calculate 5-day Directional Accuracy.
direction_accuracy = np.mean(
    np.sign(test_predictions[:-horizon] - test_predictions[horizon:]) == 
    np.sign(test[:-horizon] - test[horizon:])
)

# Print evaluation metrics.
print("4 week (one month) Horizon RMSE:", fours_weeks_rmse)
print("4 week (one month) Horizon MAE:", fours_weeks_mae)
print("4 week (one month) Horizon MAPE:", fours_weeks_mape)
print(f"5-Day Horizon Directional Accuracy: {direction_accuracy * 100:.2f}%")

# Plot the actual vs. predicted values for training and test sets.
plt.figure(figsize=(12, 6))
plt.plot(train.index, train, label="Actual - Train", color='blue')
plt.plot(test.index, test, label="Actual - Test", color='orange')

# Plot predictions on test set.
plt.plot(test.index, test_predictions, label="Predicted - Test", linestyle='--', color='red')

# Finalize the plot.
plt.legend()
plt.title("Actual vs. Predicted Values for Test Set 4 week (one month)")
plt.xlabel("Time")
plt.ylabel("Values")
plt.show()
# Out:
# 4 week (one month) Horizon RMSE: 0.027225757839605347
# 4 week (one month) Horizon MAE: 0.021021983764365326
# 4 week (one month) Horizon MAPE: 395.14094878121966
# 5-Day Horizon Directional Accuracy: 94.84%

# %% [markdown]
# | Model                              | AIC        | Training RMSE | Test RMSE | Training MAE | Test MAE | Directional Accuracy (Train) | Directional Accuracy (Test) |
# |------------------------------------|------------|---------------|-----------|--------------|----------|------------------------------|-----------------------------|
# | (1, 0, 3)x(1, 0, [1, 2], 12)       | -5117.628  | 0.0128       | 0.0196    | 0.0094       | 0.0153   | 99.77%                       | 98.71%                      |
# | (0, 0, 1)                          | -5003.852  | 0.0138       | 0.0216    | 0.0100       | 0.0170   | 99.77%                       | 98.71%                      |
# | (0, 0, 1)x(0, 0, 1, 12)            | -4731.579  | 0.0161       | 0.0189    | 0.0118       | 0.0148   | 99.77%                       | 98.71%                      |
# | (1, 0, 3)x(1, 0, [1, 2], 4)        | -5017.528  | 0.0136       | 0.0189    | 0.0098       | 0.0148   | 99.77%                       | 98.71%                      |
# | (0, 0, 3)x(2, 0, [1, 2], 4)        | -5014.996  | 0.0136       | 0.0189    | 0.0099       | 0.0148   | 99.77%                       | 98.71%                      |
# | (2, 0, 1)x(1, 0, [1, 2], 12)       | -4931.966  | 0.0143       | 0.0189    | 0.0105       | 0.0148   | 99.77%                       | 98.71%                      |

# %%
## Define SARIMAX model. 
sarimax_model = SARIMAX(train, order=(0, 0, 1), seasonal_order=(0, 0, 1, 12), exog=exo_train)
sarimax_final_fitted = sarimax_model.fit(disp=False)

# Print summary.
print(sarimax_final_fitted.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Close   No. Observations:                  876
# Model:             SARIMAX(0, 0, 1)x(0, 0, 1, 12)   Log Likelihood                2373.790
# Date:                            Sun, 10 Nov 2024   AIC                          -4731.579
# Time:                                    18:14:57   BIC                          -4693.376
# Sample:                                04-01-2004   HQIC                         -4716.966
#                                      - 01-07-2021
# Covariance Type:                              opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# rolling_mean_4w      1.4016      0.082     17.039      0.000       1.240       1.563
# rolling_mean_12w    -0.0583      0.102     -0.571      0.568      -0.259       0.142
# volatility_4w     6.996e-06   4.59e-05      0.152      0.879    -8.3e-05     9.7e-05
# lag_1               -0.3577      0.066     -5.419      0.000      -0.487      -0.228
# lag_4                0.0173      0.032      0.534      0.594      -0.046       0.081
# ma.L1                0.1330      0.082      1.615      0.106      -0.028       0.294
# ma.S.L12            -0.0214      0.033     -0.641      0.521      -0.087       0.044
# sigma2               0.0003   1.24e-05     20.944      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   4.79   Jarque-Bera (JB):                91.23
# Prob(Q):                              0.03   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.86   Skew:                             0.27
# Prob(H) (two-sided):                  0.21   Kurtosis:                         4.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Calculate residuals from the fitted model.
residuals = sarimax_final_fitted.resid

# Plot ACF and PACF for residuals.
fig, ax = plt.subplots(2, 1, figsize=(10, 8))
sm.graphics.tsa.plot_acf(residuals, lags=30, ax=ax[0])
ax[0].set_title('ACF of Residuals')
sm.graphics.tsa.plot_pacf(residuals, lags=30, ax=ax[1])
ax[1].set_title('PACF of Residuals')
plt.tight_layout()
plt.show()

# %% [markdown]
# - According to the ACF and PACF of the residuals, it is observable that most of the values will fall under the shaded area (confidence interval), showing very weak autocorrelation.
# - Also, spikes were identified at initial lags, meaning that might exist autocorrelation that the model cannot capture.

# %%
# Q-Q plot for normality check.
sm.qqplot(residuals, line='s')
plt.title('Q-Q Plot of Residuals')
plt.show()

# Histogram of residuals.
plt.figure(figsize=(8, 5))
plt.hist(residuals, bins=30, edgecolor='k')
plt.title('Histogram of Residuals')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The Q-Q plot shows that the residuals generally follows a normal distribution with deviations in its tails. Which is also observable at the histogram (similar to a bell shape).
#
# The analysis of residuals over time is extremely important, it will show how the model is handling the nuances of the data (i.e.: volatility) and by checking the constant variance (homoscedasticity).

# %%
# Plot residuals over time.
plt.figure(figsize=(10, 5))
plt.plot(residuals)
plt.title('Residuals Over Time')
plt.xlabel('Time')
plt.ylabel('Residuals')
plt.show()

# %% [markdown]
# The residuals do not shows a pattern overtime and most of the values are clustered around zero.
#
# **Note**: Because the residuals are clustered around zero does not mean that the model capture all the nuances, but in fact the residuals might be clustered due to the fact that the target variable has a very low scale (log transformation). Thus, "alternative" residuals will be calculated to obtain more insightful analysis.
#
# The standardized residuals will "adjust" the original scale to be more visually comparable.

# %% [markdown]
# - The chosen SARIMA model has a decent performance in capturing data nuances. However, times when the economy suffered any sort of turmoil (2009 market crash and 2019 Covid Pandemic) it is observable that the model was not able to fully capture the nuances in periods of high-volatility.

# %%
# Ljung-Box test for autocorrelation.
ljung_box_results = acorr_ljungbox(residuals, lags=[10, 20, 30], return_df=True)
print(ljung_box_results) # prints the results.

# Arch test for heteroscedasticity 
arch_test_stat, arch_pvalue, _, _ = het_arch(residuals)
print("ARCH Test p-value:", arch_pvalue) # prints the arch results.
# Out:
#        lb_stat     lb_pvalue
# 10  186.655076  9.705212e-35
# 20  202.412362  3.748111e-32
# 30  211.595038  3.280279e-29
# ARCH Test p-value: 4.53854381990896e-33

# %% [markdown]
# - The Ljung-Box tests the autocorrelation in the residuals, which is very low at different lags, indicating that autocorrelation is present in the residuals.
# - The ARCH test suggests the presence of heteroscedasticity and this is because the p value is very low 2.95e-23.
#
# The present model is struggling to forecast values when high-volatility is present. Indicating that next models needs to have stronger capabilities to handle volatility (a good example is GARCH) or even non-linear models (such as LSTM, GRU).
#
# Thus, models that are robust against volatility such as GARCH is a viable option to apply, as stand-alone or in combination with other models, in this case SARIMA-GARCH.
